# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
walmart= pd.read_csv("Walmart.csv")

# %%
walmart.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
walmart.tail()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %%
walmart.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
walmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
walmart.shape
# Out:
# (6435, 8)

# %%
walmart['Date'] = pd.to_datetime(walmart['Date'], dayfirst=True)
walmart= walmart.sort_values('Date')

# %%
walmart.groupby('Date')['Weekly_Sales'].sum().plot(figsize=(12,5))
plt.title('Total Weekly Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.show()

# %%
walmart['Year']= walmart['Date'].dt.year
walmart['Month']= walmart['Date'].dt.month
walmart['Day']= walmart['Date'].dt.isocalendar().week

# %%
y = walmart["Weekly_Sales"]

# %%
X = walmart[[
    "Store",
    "Holiday_Flag",
    "Temperature",
    "Fuel_Price",
    "CPI",
    "Unemployment",
    "Year",
    "Month",
    "Day"
]]

# %%
walmart
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1287     10 2010-02-05    2193048.75             0        54.34       2.962
# 5148     37 2010-02-05     536006.73             0        45.97       2.572
# 2288     17 2010-02-05     789036.02             0        23.11       2.666
# 4147     30 2010-02-05     465108.52             0        39.05       2.572
# ...     ...        ...           ...           ...          ...         ...
# 3574     25 2012-10-26     688940.94             0        56.69       3.882
# 714       5 2012-10-26     319550.77             0        71.70       3.506
# 5719     40 2012-10-26     921264.52             0        49.65       3.917
# 2573     18 2012-10-26    1127516.25             0        56.09       3.917
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Year  Month  Day
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model= RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# %%
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(((y_test-y_pred)**2).mean())

# %%
print("Mean Absolute Error(MAE):",mae)
print("Root mean Square Devation(RMSE):",rmse)
# Out:
# Mean Absolute Error(MAE): 103383.3258467752
# Root mean Square Devation(RMSE): 179168.79804330194
