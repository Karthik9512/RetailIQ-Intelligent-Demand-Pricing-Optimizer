# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
walmart= pd.read_csv("Walmart.csv")

# %%
walmart.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
walmart.tail()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %%
walmart.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
walmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
walmart.shape
# Out:
# (6435, 8)

# %%
walmart['Date'] = pd.to_datetime(walmart['Date'], dayfirst=True)

# %%
walmart['Date'] = pd.to_datetime(walmart['Date'], dayfirst=True)
walmart= walmart.sort_values('Date')

# %%
walmart.groupby('Date')['Weekly_Sales'].sum().plot(figsize=(12,5))
plt.title('Total Weekly Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Weekly Sales')
plt.show()

# %%
walmart['Year']= walmart['Date'].dt.year
walmart['Month']= walmart['Date'].dt.month
walmart['Day']= walmart['Date'].dt.isocalendar().week

# %%
y = walmart["Weekly_Sales"]

# %%
X = walmart[[
    "Store",
    "Holiday_Flag",
    "Temperature",
    "Fuel_Price",
    "CPI",
    "Unemployment",
    "Year",
    "Month",
    "Day"
    
]]

# %%
walmart
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# 5         1 2010-03-12    1439541.59             0        57.79       2.667
# 6         1 2010-03-19    1472515.79             0        54.58       2.720
# 7         1 2010-03-26    1404429.92             0        51.45       2.732
# 8         1 2010-04-02    1594968.28             0        62.27       2.719
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=200, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# %%
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(((y_test-y_pred)**2).mean())

# %%
print("Mean Absolute Error(MAE):",mae)
print("Root mean Square Devation(RMSE):",rmse)
# Out:
# Mean Absolute Error(MAE): 103383.3258467752
# Root mean Square Devation(RMSE): 179168.79804330194

# %%
walmart= walmart.sort_values(['Store','Date'])

# %%
walmart['lag_1']= walmart.groupby("Store")['Weekly_Sales'].shift(1)
walmart['lag_2']= walmart.groupby("Store")['Weekly_Sales'].shift(2)
walmart['lag_4']= walmart.groupby("Store")['Weekly_Sales'].shift(4)

# %%
walmart = walmart.dropna()

# %%
walmart
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 8         1 2010-04-02    1594968.28             0        62.27       2.719
# 9         1 2010-04-09    1545418.53             0        65.86       2.770
# 10        1 2010-04-16    1466058.28             0        66.32       2.808
# 11        1 2010-04-23    1391256.12             0        64.84       2.795
# 12        1 2010-04-30    1425100.71             0        67.41       2.780
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
# ...

# %%
# walmart= walmart.drop(columns='lag_3')

# %%
walmart
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 8         1 2010-04-02    1594968.28             0        62.27       2.719
# 9         1 2010-04-09    1545418.53             0        65.86       2.770
# 10        1 2010-04-16    1466058.28             0        66.32       2.808
# 11        1 2010-04-23    1391256.12             0        64.84       2.795
# 12        1 2010-04-30    1425100.71             0        67.41       2.780
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
# ...

# %%
plt.figure(figsize=(12,6))

plt.plot(y_test.values[:100], label= 'Actual Sales')
plt.plot(y_pred[:100], label= 'Predicted Sales')

plt.title("Actual Vs Predicated Weekly Sales")
plt.xlabel('Time')
plt.ylabel('Sales')
plt.legend()

plt.show()

# %%
importance = model.feature_importances_
feature_importance = pd.DataFrame({
    "Feature":X.columns,
    'Importance': importance
})
feature_importance = feature_importance.sort_values(by="Importance", ascending=False)

# %%
feature_importance
# Out:
#         Feature  Importance
# 0         Store    0.617689
# 4           CPI    0.168014
# 5  Unemployment    0.128200
# 8           Day    0.059903
# 3    Fuel_Price    0.009825
# 2   Temperature    0.009806
# 7         Month    0.003115
# 6          Year    0.001947
# 1  Holiday_Flag    0.001501

# %%
plt.figure(figsize=(10,6))
plt. barh(feature_importance['Feature'], feature_importance['Importance'])

plt.xlabel('Importance')
plt.ylabel('Feature Importance in Sales Prediction')

plt.gca().invert_yaxis()

plt.show()

# %%
latest_data = walmart.sort_values("Date").groupby("Store").tail(1)

# %%
future_data = latest_data.copy()

# %%
walmart["Date"] = pd.to_datetime(walmart["Date"])

# %%
future_data["lag_1"]= latest_data["Weekly_Sales"]
future_data["lag_2"]= latest_data["lag_1"]
future_data["lag_4"]= latest_data["lag_2"]

future_data["Day"] = future_data["Day"] + 1

# %%
X = walmart[[
    "Store",
    "Holiday_Flag",
    "Temperature",
    "Fuel_Price",
    "CPI",
    "Unemployment",
    "Year",
    "Month",
    "Week",
    "lag_1",
    "lag_2",
    "lag_4"
]]

y = walmart["Weekly_Sales"]

# %%
future_X
# Out:
#       Store  Holiday_Flag  Temperature  Fuel_Price         CPI  Unemployment  \
# 6148     43             0        69.17       3.506  214.741539         8.839
# 1858     13             0        46.97       3.755  131.193097         5.621
# 5576     39             0        72.90       3.506  222.113657         6.228
# 285       2             0        69.79       3.506  223.078337         6.170
# 2430     17             0        39.94       3.755  131.193097         5.527
# 4003     28             0        65.95       4.301  131.193097        10.199
# 857       6             0        72.34       3.506  225.068625         5.329
# 5719     40             0        49.65       3.917  138.728161         4.145
# 3002     21             0        70.50       3.506  223.078337         6.170
# 3431     24             0        55.16       4.071  138.728161         8.693
# 4575     32             0        47.22       3.686  199.219532         7.557
# ...

# %%
future_X = future_data[[
    "Store",
    "Holiday_Flag",
    "Temperature",
    "Fuel_Price",
    "CPI",
    "Unemployment",
    "Year",
    "Month",
    "Day",
    "lag_1",
    "lag_2",
    "lag_4"
]]

# %%
walmart["lag_1"] = walmart.groupby("Store")["Weekly_Sales"].shift(1)
walmart["lag_2"] = walmart.groupby("Store")["Weekly_Sales"].shift(2)
walmart["lag_4"] = walmart.groupby("Store")["Weekly_Sales"].shift(4)

# %%
walmart['Date'] = pd.to_datetime(walmart['Date'], dayfirst=True)

# %%
future_data["lag_1"] = latest_data["Weekly_Sales"]
future_data["lag_2"] = latest_data["lag_1"]
future_data["lag_4"] = latest_data["lag_2"]

# %%
future_data
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6148     43 2012-10-26     587603.55             0        69.17       3.506
# 1858     13 2012-10-26    2035189.66             0        46.97       3.755
# 5576     39 2012-10-26    1569502.00             0        72.90       3.506
# 285       2 2012-10-26    1834458.35             0        69.79       3.506
# 2430     17 2012-10-26     943465.29             0        39.94       3.755
# 4003     28 2012-10-26    1213860.61             0        65.95       4.301
# 857       6 2012-10-26    1431426.34             0        72.34       3.506
# 5719     40 2012-10-26     921264.52             0        49.65       3.917
# 3002     21 2012-10-26     675202.87             0        70.50       3.506
# 3431     24 2012-10-26    1307182.29             0        55.16       4.071
# 4575     32 2012-10-26    1219979.29             0        47.22       3.686
# ...

# %%
future_data["Predicted_Sales"] = model.predict(future_X)

# %%
print(future_data[["Store", "Predicted_Sales"]])
# Out:
#       Store  Predicted_Sales
# 6148     43     7.557697e+05
# 1858     13     2.665074e+06
# 5576     39     1.883596e+06
# 285       2     2.401040e+06
# 2430     17     1.154056e+06
# 4003     28     1.438130e+06
# 857       6     1.878724e+06
# 5719     40     1.211807e+06
# 3002     21     8.486485e+05
# 3431     24     1.771142e+06
# 4575     32     1.439858e+06
# 714       5     3.765794e+05
# 2716     19     1.776912e+06
# 1572     11     1.730074e+06
# 3717     26     1.283963e+06
# 1143      8     1.141332e+06
# 5290     37     6.737557e+05
# 4718     33     3.039716e+05
# 1715     12     1.236228e+06
# 2144     15     7.141455e+05
# 4289     30     4.376739e+05
# 142       1     1.905445e+06
# 6291     44     3.641457e+05
# 571       4     2.746352e+06
# 5862     41     1.788786e+06
# 6005     42     6.381286e+05
# 428       3     4.238927e+05
# 5433     38     4.996186e+05
# 1000      7     6.195219e+05
# 4432     31     1.810176e+06
# 2001     14     1.787727e+06
# ...
